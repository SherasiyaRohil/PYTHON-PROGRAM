# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 6</b></center>
# <center><b><h4>Roll No. : 244 </b></center>
# <center><b><h4>Name :Sherasiya Rohil</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to find sum of all the elements in a List.

# %%
l=[]
n=int(input("enter the number"))
sum=0
for i in range(1,n+1):
    n1=int(input("enter n1"))
    sum+=i
    
sum
# Out:
# enter the number 5
# enter n1 1
# enter n1 2
# enter n1 3
# enter n1 4
# enter n1 5
# 15

# %% [markdown]
# ### 02) WAP to find largest element in a List.

# %%
l=[1,2,3,4,5]
larg=max(l)
print(larg)
# Out:
# 5

# %% [markdown]
# ### 03) WAP to find the length of a List.

# %%
l=[1,2,3,4,5,6]
l1=len(l)
l1
# Out:
# 6

# %% [markdown]
# ### 04) WAP to interchange first and last elements in a list.

# %%
l[0],l[-1]=l[-1],l[0]
l
# Out:
# [6, 2, 3, 4, 5, 1]

# %% [markdown]
# ### 05) WAP to split the List into two parts and append the first part to the end.

# %%
l=[1,2,3,4,5,]
l1=l[:3]
l2=l[3:]
l=l2+l1
l
# Out:
# [4, 5, 1, 2, 3]

# %% [markdown]
# ### 06) WAP to interchange the elements on two positions entered by a user.

# %%
l=[1,2,3,4,5,6]
p1=int(input("enter a1"))
p2=int(input("enter a2"))
l[p1],l[p2]=l[p2],l[p1]
l
# Out:
# enter a1 2
# enter a2 3
# [1, 2, 4, 3, 5, 6]

# %% [markdown]
# ### 07) WAP to reverse the list entered by user.

# %%
l=[]
n=int(input("enter the ele"))
for i in range(1,n+1):
     l.append(int(input("enter the n1")))
print(l[::-1])
# Out:
# enter the ele 3
# enter the n1 1
# enter the n1 2
# enter the n1 3
# [3, 2, 1]

# %% [markdown]
# ### 08) WAP to print even numbers in a list.

# %%
l=[1,2,4,6,8,7,3,10]
for i in l:
    if i%2==0:
        print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ### 09) WAP to count unique items in a list.

# %%
l=[1,2,2,3,3,3,4,4,4,5,5]
r=[]
for i in l:
    if i not in r:
        r.append(i)
print(r)
len(r)
# Out:
# [1, 2, 3, 4, 5]
# 5

# %% [markdown]
# ### 10) WAP to copy a list.

# %%
l=[1,2,3,4,5]
cp=l.copy()
cp
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### 11) WAP to print all odd numbers in a given range.

# %%
n=11
for i in range(n+1):
    if i%2!=0:
        print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %% [markdown]
# ### 12) WAP to count occurrences of an element in a list.

# %%
l=[1,2,2,3,3,3,4,4,5,6]
n=[]
for i in l:
    if i not in n:
        n.append(i)
for i in  n:
    print(f'count of{i} is {l.count(i)}')
# Out:
# count of1 is 1
# count of2 is 2
# count of3 is 3
# count of4 is 2
# count of5 is 1
# count of6 is 1

# %% [markdown]
# ### 13) WAP to find second largest number in a list.

# %%
l=[4,2,3,6,5,1]
l.sort()
l[-2]
# Out:
# 5

# %% [markdown]
# ### 14) WAP to extract elements with frequency greater than K.

# %%
l=[1,2,2,2,3,6]
k=int(input("enter n"))
u=[]

for i in l:
    if l.count(i)>k:
        u.append(i)
u
# Out:
# enter n 2
# [2, 2, 2]

# %% [markdown]
# ### 15) WAP to create a list of squared numbers from 0 to 9 with and without using List Comprehension.

# %%
# l=[]
# for i in range(0,10):
    # l.append(i**2)
#l

[i**2 for i in range(0,10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ### 16) WAP to create a new list (fruit whose name starts with 'b') from the list of fruits given by user.

# %%
f=["banana","chary","apple"]
l=[]
for i in f:
    if i[0]=='b':
        l.append(i)
l
# Out:
# ['banana']

# %% [markdown]
# ### 17) WAP to create a list of common elements from given two lists.

# %%
l=[1,2,3,4,5]
l2=[2,3,4,5,6]
c=[i for i in l if i in l2]
print(c)
# Out:
# [2, 3, 4, 5]
